# %% [markdown]
# <a href="https://colab.research.google.com/github/amal750/project/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_34537/3703241522.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 uploaded=files.upload()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in upload(target_dir)
#      67   """
#      68
# ---> 69   uploaded_files = _upload_files(multiple=True)
#      70   # Mapping from original filename to filename as saved locally.
#      71   local_filenames = dict()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in _upload_files(multiple)
#     167
#     168   while result['action'] != 'complete':
# --> 169     result = _output.eval_js(
#     170         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
#     171             output_id=output_id
#
# ...

# %%
# !pip install opencv-python matplotib pillow numpy
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement matplotib (from versions: none)
# ERROR: No matching distribution found for matplotib

# %%
import os
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from PIL import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_34537/1971338611.py in <cell line: 0>()
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
# ----> 6 from PIL import image
#
# ImportError: cannot import name 'image' from 'PIL' (/usr/local/lib/python3.12/dist-packages/PIL/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !apt-get install -y p7zip-full
!7z x /content/archive.zip -o/content/dataset

# %%
# !ls /content/dataset

# %%
DATASENT_PATH="/content/dataset"
IMAGE_PATH=os.path.join(DATASENT_PATH,"test/images")
images=glob.glob(os.path.join(IMAGE_PATH,"*.jpg"))
print("Total images:",len(images))
for i,img in enumerate(images[:5]):
  print(f"[{i+1}] {img}")

# %%
def load_image(image_path):
  img_bgr=cv2.imread(image_path)
  img_rgb=cv2.cvtColorcolor(img_bgr,cv2.Color_BRG2RGB)
  return img_bgr,img_rgb

# %%
def preprocess(img_bgr):
  gray=cv2.cvtColorcolor(img_bgr,cv2.COLOR_BQR2GRAY)

  resized=cv2.resize(gray,(640,640))
  return gray,resized

# %%
def filtering(gray):
  guassian=cv2.GaussianBlur(gray,(5,5),0)

  median=cv2.medianBlur(gray,5)

  bilateral=cv2.bilateralFilter(gray,9,75,75)
  return gaussian,median,bilateral

# %%
def edge_detection(filtered):
canny=cv2.Canny(filtered,100,200)

sobelx=cv2.Sobel(filtered,cv2.CV_64F,1,0,ksize=5)
sobely=cv2.Sobel(filtered,cv2.CV_64F,0,1,ksize=5)
sobel=cv2.magnitude(sobelx,sobely)
return canny,sobel

# %%
def segmentation(gray):

  thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

  adaptive-cv2.adaptiveTheshold(gray,255,cv2.ADAPTIVE_THRESHOLD_GAUSSIAN_C,cv2.THRES_BINARY,11,2)
  return thresh,adaptive

# %%
def show_results(original,gray,gaussian,median,edges,thresh):

  plt.figure(figsize=(15,10))

  plt.subplot(2,3,1)
  plt.title("original")
  plt.imshow(original)
  plt.axis("off")


  plt.subplot(2,3,2)
  plt.title("Gray")
  plt.imshow(gray,cmap'gray')
  plt.axis("off")


  plt.subplot(2,3,3)
  plt.title("Gaussian filter")
  plt.imshow(gaussian,cmap='gray')
  plt.axis("off")


  plt.subplot(2,3,4)
  plt.title("Median filter")
  plt.imshow(median,cmap='gray')
  plt.axis("off")


  plt.subplot(2,3,5)
  plt.title("Canny edge detection")
  plt.imshow(edges,cmap='gray')
  plt.axis("off")


  plt.subplot(2,3,6)
  plt.title("Threshold segmentation")
  plt.imshow(thresh,cap='gray')
  plt.axis("off")

  plt.show()
